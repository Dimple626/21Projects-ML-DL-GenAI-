# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimple626/21Projects-ML-DL-GenAI-/blob/main/Project16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Resume Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("palaksood97/resume-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 11.1M/11.1M [00:00<00:00, 119MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/palaksood97/resume-dataset/versions/1

# %%
import os
print("Files:", os.listdir(path))
# Out:
# Files: ['Resumes']

# %% [markdown]
# Choosing Random Resume

# %%
# For converting PDF to images
# !pip install pdf2image
# !apt-get install -y poppler-utils
# !pip install pillow
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.11 [186 kB]
# Fetched 186 kB in 1s (220 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126718 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.11_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.11) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.11) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...

# %% [markdown]
# Convert pdf to images

# %%
from pdf2image import convert_from_path
import shutil

output_dir = "resume_images"
os.makedirs(output_dir, exist_ok=True)

for filename in random_files:
    pdf_path = os.path.join(path, filename)
    # Convert all pages in PDF to images (jpg/png)
    images = convert_from_path(pdf_path)
    for page_num, img in enumerate(images):
        out_file = f"{output_dir}/{filename}_page{page_num+1}.png"
        img.save(out_file, "PNG")
        print("Saved:", out_file)

# %% [markdown]
# View Images

# %%
from IPython.display import Image, display

for filename in os.listdir(output_dir)[:5]:  # Show first 5 for speed
    display(Image(filename=os.path.join(output_dir, filename)))

# %%
# !pip install pytesseract
import pytesseract

for imgfile in os.listdir(output_dir)[:3]:  # Show results for 3
    img_path = os.path.join(output_dir, imgfile)
    text = pytesseract.image_to_string(img_path)
    print(f"Text from {imgfile}:\n{text}")

# %%
from IPython.display import Image, display

image_files = [f for f in os.listdir(output_dir) if f.lower().endswith('.png')]
for filename in image_files[:5]:  # First 5 images show karo
    display(Image(filename=os.path.join(output_dir, filename)))

# %%
import kagglehub
path = kagglehub.dataset_download("palaksood97/resume-dataset")
print("Path:", path)
print("Files:", os.listdir(path))
# Out:
# Using Colab cache for faster access to the 'resume-dataset' dataset.
# Path: /kaggle/input/resume-dataset
# Files: ['Resumes']

# %%
import os
print("Available files in downloaded path:")
print(os.listdir(path))
# Out:
# Available files in downloaded path:
# ['Resumes']

# %%
import random
from pdf2image import convert_from_path

output_dir = "resume_images"
os.makedirs(output_dir, exist_ok=True)

num_files = min(20, len(pdfs))
random_files = random.sample(pdfs, num_files)

for filename in random_files:
    pdf_path = os.path.join(resume_folder, filename)
    try:
        images = convert_from_path(pdf_path)
        for page_num, img in enumerate(images):
            out_file = os.path.join(output_dir, f"{filename}_page{page_num+1}.png")
            img.save(out_file, "PNG")
            print("Saved:", out_file)
    except Exception as e:
        print(f"Failed for {filename}: {e}")

# %%
from IPython.display import Image, display

image_files = [f for f in os.listdir(output_dir) if f.lower().endswith('.png')]
for filename in image_files[:5]:
    display(Image(filename=os.path.join(output_dir, filename)))

# %%
import os
from pdf2image import convert_from_path

resume_folder = os.path.join(path, "Resumes")
pdfs = [f for f in os.listdir(resume_folder) if f.lower().endswith('.pdf')]
print("PDFs found:", pdfs)

output_dir = "resume_images"
os.makedirs(output_dir, exist_ok=True)

import random
num_files = min(20, len(pdfs))
random_files = random.sample(pdfs, num_files)

for filename in random_files:
    pdf_path = os.path.join(resume_folder, filename)
    try:
        images = convert_from_path(pdf_path)
        for page_num, img in enumerate(images):
            out_file = os.path.join(output_dir, f"{filename}_page{page_num+1}.png")
            img.save(out_file, "PNG")
            print("Saved:", out_file)  # This should show file names being saved!
    except Exception as e:
        print(f"Failed for {filename}: {e}")

print("Images:", os.listdir(output_dir))  # Now this should NOT be empty
# Out:
# PDFs found: []
# Images: []

# %%
from IPython.display import Image, display

image_files = [f for f in os.listdir(output_dir) if f.lower().endswith('.png')]
for filename in image_files[:5]:
    display(Image(filename=os.path.join(output_dir, filename)))

# %%
# !apt-get install -y poppler-utils
# !pip install pdf2image
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.11).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# ...

# %%
import os

resume_folder = os.path.join(path, "Resumes")
for root, dirs, files in os.walk(resume_folder):
    print(f"Inside: {root}")
    for file in files:
        print(file)
# Out:
# Inside: /kaggle/input/resume-dataset/Resumes
# Venkata_Sr.PHP_Developer.docx
# Uday_Maripelly.docx
# Kuppurajbabu_BA.docx
# Harika_java.docx
# KIRAN KUMAR.docx
# Shail_Tank-Business Analyst .docx
# kalyan das.docx
# Adelina_Erimia_PMP1.docx
# mounika BA resume 7.docx
# Mounika_P.docx
# Krishna_BSA.docx
# Resume Vishal PM - MSIS, PMP-PMI.docx
# Madhu_BA_AW.DOCX
# Ujvala BA Feb 20.docx
# Sundar_Java_8+ Years..docx
# SAURABH_PM.docx
# Vijay Bhargav.docx
# Sri Gati.docx
# jeck P.docx
# Srivatsan_Project_Manager.docx
# Tejaswi-resume.docx
# Alekhya Resume.docx
# Vikash_BA_Ab.docx
# Naren Sr.BA.docx
# RaviBurra_Certified PM_DevOps.docx
# Mitali Barman_Resume.docx
# Sarath M.docx
# Bharatha BA Resume.docx
# Mani_Hadoop.docx
# Naveen Kumar Bandela.docx
# PM RESUME.docx
# Naresh V.docx
# Tarun Resume.docx
# RaviRaju_Resume.docx
# Gokul Selvam S PM.docx
# Robinson.docx
# mahesh_Java.docx
# Priya_Sharma.docx
# Varun.docx
# Sougandh_Java Fullstack Developer.docx
# Vivek.BSA.docx
# ...

# %%
import shutil, os

resume_folder = os.path.join(path, "Resumes")
work_dir = "/content/resume_docs"
os.makedirs(work_dir, exist_ok=True)

docx_files = [f for f in os.listdir(resume_folder) if f.lower().endswith('.docx')]
for docx_file in docx_files[:20]:
    shutil.copy(os.path.join(resume_folder, docx_file), work_dir)
print("Copied to:", work_dir)
# Out:
# Copied to: /content/resume_docs

# %%
# Install LibreOffice
# !apt-get install -y libreoffice

import os

docx_dir = "/content/resume_docs"
pdf_dir = "/content/resume_pdfs"
os.makedirs(pdf_dir, exist_ok=True)

docx_files = [f for f in os.listdir(docx_dir) if f.lower().endswith('.docx')]
for docx_file in docx_files:
    src_path = os.path.join(docx_dir, docx_file)
    # !libreoffice --headless --convert-to pdf "{src_path}" --outdir "{pdf_dir}"
print("PDFs generated:", [f for f in os.listdir(pdf_dir) if f.endswith('.pdf')])
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono
#   fonts-noto-ui-core fonts-opensymbol fonts-sil-gentium
#   fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3 hunspell-en-us
#   libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcolamd2 libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1
#   libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data libfbclient2
# ...

# %%
from pdf2image import convert_from_path

output_dir = "/content/resume_images"
os.makedirs(output_dir, exist_ok=True)

pdfs = [f for f in os.listdir(pdf_folder) if f.lower().endswith('.pdf')]
for filename in pdfs:
    pdf_path = os.path.join(pdf_folder, filename)
    try:
        images = convert_from_path(pdf_path)
        for page_num, img in enumerate(images):
            out_file = os.path.join(output_dir, f"{filename}_page{page_num+1}.png")
            img.save(out_file, "PNG")
            print("Saved:", out_file)
    except Exception as e:
        print(f"Failed for {filename}: {e}")

print("Images:", os.listdir(output_dir))
# Out:
# Saved: /content/resume_images/jeck P.pdf_page1.png
# Saved: /content/resume_images/jeck P.pdf_page2.png
# Saved: /content/resume_images/jeck P.pdf_page3.png
# Saved: /content/resume_images/jeck P.pdf_page4.png
# Saved: /content/resume_images/jeck P.pdf_page5.png
# Saved: /content/resume_images/jeck P.pdf_page6.png
# Saved: /content/resume_images/jeck P.pdf_page7.png
# Saved: /content/resume_images/Mounika_P.pdf_page1.png
# Saved: /content/resume_images/Mounika_P.pdf_page2.png
# Saved: /content/resume_images/Mounika_P.pdf_page3.png
# Saved: /content/resume_images/Mounika_P.pdf_page4.png
# Saved: /content/resume_images/Mounika_P.pdf_page5.png
# Saved: /content/resume_images/Madhu_BA_AW.pdf_page1.png
# Saved: /content/resume_images/Madhu_BA_AW.pdf_page2.png
# Saved: /content/resume_images/Madhu_BA_AW.pdf_page3.png
# Saved: /content/resume_images/Shail_Tank-Business Analyst .pdf_page1.png
# Saved: /content/resume_images/Shail_Tank-Business Analyst .pdf_page2.png
# ...

# %%
from IPython.display import Image, display
import os

output_dir = "/content/resume_images"  # change path if needed
image_files = [f for f in os.listdir(output_dir) if f.lower().endswith('.png')]

# Preview first 5 images
for filename in image_files[:5]:
    display(Image(filename=os.path.join(output_dir, filename)))
